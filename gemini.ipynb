# %%
from google import genai
from google.genai import types

# Configure the library with your API key first
genai.configure(api_key="AIzaSyDSeDhmbJ1JmVv-BIZNzkX9eCN4xdN64qI")

# Now, initialize the client
client = genai.Client()

prompt = "What are the best Italian restaurants within a 15-minute walk from here?"

response = client.models.generate_content(
    model='gemini-2.5-flash-lite',
    contents=prompt,
    config=types.GenerateContentConfig(
        tools=[types.Tool(google_maps=types.GoogleMaps())],
        # Optionally provide the relevant location context (this is in Los Angeles)
        tool_config=types.ToolConfig(retrieval_config=types.RetrievalConfig(
            lat_lng=types.LatLng(
                latitude=34.050481, longitude=-118.248526))),
    ),
)

print(response.text)

if grounding := response.candidates[0].grounding_metadata:
  if grounding.grounding_chunks:
    print("Google Maps sources:")
    for chunk in grounding.grounding_chunks:
      print(f'- [{chunk.maps.title}]({chunk.maps.uri})')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 5
#       2 from google.genai import types
#       4 # Configure the library with your API key first
# ----> 5 genai.configure(api_key="AIzaSyDSeDhmbJ1JmVv-BIZNzkX9eCN4xdN64qI")
#       7 # Now, initialize the client
#       8 client = genai.Client()
#
# AttributeError: module 'google.genai' has no attribute 'configure'

# %%
import os  # For secure handling of environment variables
import google.generativeai as genai  # Correct import for the SDK (note: use this instead of 'from google import genai' for standard usage)

# Securely set your API key (replace with your actual key or load from env)
# Best practice: Set GOOGLE_API_KEY as an environment variable outside the code
genai.configure(api_key="AIzaSyDSeDhmbJ1JmVv-BIZNzkX9eCN4xdN64qI")  # Or directly: api_key="YOUR_API_KEY_HERE"

# Now initialize the model (adjusted from your code for standard SDK usage)
model = genai.GenerativeModel(
    model_name="gemini-1.5-flash",  # Or other supported model
    tools=[genai.types.Tool(google_maps=genai.types.GoogleMaps(enable_widget=True))],  # Enable Maps tool
    tool_config=genai.types.ToolConfig(
        retrieval_config=genai.types.RetrievalConfig(
            lat_lng=genai.types.LatLng(latitude=37.7749, longitude=-122.4194)  # San Francisco example
        )
    )
)

# Prompt for a bar crawl suggestion
prompt = "Suggest a bar crawl with 3 highly rated spots near me that serve craft beer and have live music."

# Generate content
response = model.generate_content(prompt)

print(response.text)  # Grounded response with venue suggestions
# Extract and render sources from response.grounding_metadata.grounding_chunks
# Use response.google_maps_widget_context_token to render widget in JS
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 11
#       6 genai.configure(api_key="AIzaSyDSeDhmbJ1JmVv-BIZNzkX9eCN4xdN64qI")  # Or directly: api_key="YOUR_API_KEY_HERE"
#       8 # Now initialize the model (adjusted from your code for standard SDK usage)
#       9 model = genai.GenerativeModel(
#      10     model_name="gemini-1.5-flash",  # Or other supported model
# ---> 11     tools=[genai.types.Tool(google_maps=genai.types.GoogleMaps(enable_widget=True))],  # Enable Maps tool
#      12     tool_config=genai.types.ToolConfig(
#      13         retrieval_config=genai.types.RetrievalConfig(
#      14             lat_lng=genai.types.LatLng(latitude=37.7749, longitude=-122.4194)  # San Francisco example
#      15         )
#      16     )
#      17 )
#      19 # Prompt for a bar crawl suggestion
# ...

# %%
# !pip install -U google-genai
# Out:
# ...
#      ---------------------------------------- 0.0/45.8 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/45.8 kB ? eta -:--:--
#      ----------------- -------------------- 20.5/45.8 kB 162.5 kB/s eta 0:00:01
#      ---------------------------------- --- 41.0/45.8 kB 245.8 kB/s eta 0:00:01
#      -------------------------------------- 45.8/45.8 kB 252.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/238.5 kB ? eta -:--:--
#    ----------------- ---------------------- 102.4/238.5 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 238.5/238.5 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.2
#     Uninstalling tenacity-8.2.2:
#       Successfully uninstalled tenacity-8.2.2
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.4.0
#     Uninstalling google-genai-1.4.0:
#       Successfully uninstalled google-genai-1.4.0
# ...

# %%
# test_maps_grounding.py
import os
from google import genai
from google.genai import types

client = genai.Client(api_key="AIzaSyDSeDhmbJ1JmVv-BIZNzkX9eCN4xdN64qI")

contents = ("Plan me an evening in NYC to try different Halal carts give 4 locations, also give a dessert location near last one")

resp = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=contents,
    config=types.GenerateContentConfig(
        tools=[types.Tool(google_maps=types.GoogleMaps(enable_widget=True))],
        tool_config=types.ToolConfig(
            retrieval_config=types.RetrievalConfig(
                lat_lng=types.LatLng(latitude=42.3496, longitude=-71.0806)
            )
        ),
    ),
)

print("\n=== TEXT ===\n", resp.text)

c0 = resp.candidates[0]
gm = c0.grounding_metadata
print("\n=== MAPS SOURCES ===")
print(gm.grounding_chunks)  # place URIs, review snippets, etc.
print("\n=== WIDGET TOKEN ===\n", gm.google_maps_widget_context_token)
# Out:
# === TEXT ===
#  Here's a delicious plan for an evening exploring Halal carts in NYC, followed by a sweet treat:
#
# **Halal Cart Crawl:**
#
# 1.  **The Halal Guys:** Start your evening at the iconic The Halal Guys, located at 6th Avenue & W 53rd Street, New York, NY 10019. This famous food stand serves chicken and beef gyros, along with other Middle Eastern favorites. It boasts a 4.3-star rating from over 13,000 reviews and is open until 4 AM or 5 AM.
# 2.  **Adel's Famous Halal Food:** Next, head to Adel's Famous Halal Food at 1221 6th Ave, New York, NY 10020, very close to your first stop. This popular Middle Eastern food truck offers halal gyros and is highly-rated with 4.3 stars from over 4,800 reviews. Adel's is known for its chicken and lamb over rice, falafel, and gyro sandwiches.
# ...
